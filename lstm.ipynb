# %% [markdown]
# <a href="https://colab.research.google.com/github/ravinasha/mac/blob/main/lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
faqs = """About the Program
What is the course fee for  Data Science Mentorship Program (DSMP 2023)
The course follows a monthly subscription model where you have to make monthly payments of Rs 799/month.
What is the total duration of the course?
The total duration of the course is 7 months. So the total course fee becomes 799*7 = Rs 5600(approx.)
What is the syllabus of the mentorship program?
We will be covering the following modules:
Python Fundamentals
Python libraries for Data Science
Data Analysis
SQL for Data Science
Maths for Machine Learning
ML Algorithms
Practical ML
MLOPs
Case studies
You can check the detailed syllabus here - https://learnwith.campusx.in/courses/CampusX-Data-Science-Mentorship-Program-637339afe4b0615a1bbed390
Will Deep Learning and NLP be a part of this program?
No, NLP and Deep Learning both are not a part of this program’s curriculum.
What if I miss a live session? Will I get a recording of the session?
Yes all our sessions are recorded, so even if you miss a session you can go back and watch the recording.
Where can I find the class schedule?
Checkout this google sheet to see month by month time table of the course - https://docs.google.com/spreadsheets/d/16OoTax_A6ORAeCg4emgexhqqPv3noQPYKU7RJ6ArOzk/edit?usp=sharing.
What is the time duration of all the live sessions?
Roughly, all the sessions last 2 hours.
What is the language spoken by the instructor during the sessions?
Hinglish
How will I be informed about the upcoming class?
You will get a mail from our side before every paid session once you become a paid user.
Can I do this course if I am from a non-tech background?
Yes, absolutely.
I am late, can I join the program in the middle?
Absolutely, you can join the program anytime.
If I join/pay in the middle, will I be able to see all the past lectures?
Yes, once you make the payment you will be able to see all the past content in your dashboard.
Where do I have to submit the task?
You don’t have to submit the task. We will provide you with the solutions, you have to self evaluate the task yourself.
Will we do case studies in the program?
Yes.
Where can we contact you?
You can mail us at nitish.campusx@gmail.com
Payment/Registration related questions
Where do we have to make our payments? Your YouTube channel or website?
You have to make all your monthly payments on our website. Here is the link for our website - https://learnwith.campusx.in/
Can we pay the entire amount of Rs 5600 all at once?
Unfortunately no, the program follows a monthly subscription model.
What is the validity of monthly subscription? Suppose if I pay on 15th Jan, then do I have to pay again on 1st Feb or 15th Feb
15th Feb. The validity period is 30 days from the day you make the payment. So essentially you can join anytime you don’t have to wait for a month to end.
What if I don’t like the course after making the payment. What is the refund policy?
You get a 7 days refund period from the day you have made the payment.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmail.com
Post registration queries
Till when can I view the paid videos on the website?
This one is tricky, so read carefully. You can watch the videos till your subscription is valid. Suppose you have purchased subscription on 21st Jan, you will be able to watch all the past paid sessions in the period of 21st Jan to 20th Feb. But after 21st Feb you will have to purchase the subscription again.
But once the course is over and you have paid us Rs 5600(or 7 installments of Rs 799) you will be able to watch the paid sessions till Aug 2024.
Why lifetime validity is not provided?
Because of the low course fee.
Where can I reach out in case of a doubt after the session?
You will have to fill a google form provided in your dashboard and our team will contact you for a 1 on 1 doubt clearance session
If I join the program late, can I still ask past week doubts?
Yes, just select past week doubt in the doubt clearance google form.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmai.com
Certificate and Placement Assistance related queries
What is the criteria to get the certificate?
There are 2 criterias:
You have to pay the entire fee of Rs 5600
You have to attempt all the course assessments.
I am joining late. How can I pay payment of the earlier months?
You will get a link to pay fee of earlier months in your dashboard once you pay for the current month.
I have read that Placement assistance is a part of this program. What comes under Placement assistance?

"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
len(tokenizer.word_index)
# Out:
# 258

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'you': 2,
#  'i': 3,
#  'to': 4,
#  'a': 5,
#  'of': 6,
#  'have': 7,
#  'is': 8,
#  'will': 9,
#  'can': 10,
#  'what': 11,
#  'program': 12,
#  'course': 13,
#  'in': 14,
#  'all': 15,
#  'for': 16,
#  'and': 17,
#  'pay': 18,
#  'payment': 19,
#  'on': 20,
#  'make': 21,
#  'be': 22,
#  'if': 23,
#  'do': 24,
#  'am': 25,
#  'subscription': 26,
#  'where': 27,
#  'rs': 28,
#  'we': 29,
#  'campusx': 30,
#  'this': 31,
#  'session': 32,
#  'our': 33,
#  'sessions': 34,
#  'paid': 35,
#  'able': 36,
#  'your': 37,
#  'website': 38,
#  'fee': 39,
#  'data': 40,
#  'monthly': 41,
#  'month': 42,
#  'get': 43,
#  'yes': 44,
#  'once': 45,
#  'join': 46,
#  'past': 47,
#  'feb': 48,
#  'science': 49,
#  '7': 50,
#  'so': 51,
#  '5600': 52,
#  'not': 53,
#  'watch': 54,
#  'google': 55,
#  'by': 56,
#  'com': 57,
#  'mail': 58,
#  'from': 59,
#  'contact': 60,
#  'us': 61,
#  'at': 62,
#  'doubt': 63,
#  'mentorship': 64,
#  'payments': 65,
#  '799': 66,
#  'total': 67,
#  'duration': 68,
#  'months': 69,
#  'learning': 70,
#  'case': 71,
#  'https': 72,
#  'part': 73,
#  'are': 74,
#  'see': 75,
#  'late': 76,
#  'dashboard': 77,
#  'task': 78,
#  'don’t': 79,
#  'nitish': 80,
#  'or': 81,
#  'validity': 82,
#  '15th': 83,
#  'jan': 84,
#  'period': 85,
#  'after': 86,
#  'till': 87,
#  '21st': 88,
#  'placement': 89,
#  'assistance': 90,
#  'about': 91,
#  'follows': 92,
#  'model': 93,
#  'syllabus': 94,
#  'python': 95,
#  'ml': 96,
#  'studies': 97,
#  'here': 98,
#  'learnwith': 99,
#  'deep': 100,
#  'nlp': 101,
#  'no': 102,
#  'miss': 103,
#  'live': 104,
#  'recording': 105,
#  'class': 106,
#  'time': 107,
#  '2': 108,
#  'how': 109,
#  'absolutely': 110,
#  'middle': 111,
#  'anytime': 112,
#  'submit': 113,
#  'gmail': 114,
#  'registration': 115,
#  'related': 116,
#  'link': 117,
#  'entire': 118,
#  'suppose': 119,
#  'again': 120,
#  'days': 121,
#  'day': 122,
#  'refund': 123,
#  'living': 124,
#  'outside': 125,
#  'india': 126,
#  'should': 127,
#  'sending': 128,
#  'queries': 129,
#  'videos': 130,
#  'read': 131,
#  'but': 132,
#  'provided': 133,
#  'form': 134,
#  '1': 135,
#  'clearance': 136,
#  'week': 137,
#  'certificate': 138,
#  'earlier': 139,
#  'dsmp': 140,
#  '2023': 141,
#  'becomes': 142,
#  'approx': 143,
#  'covering': 144,
#  'following': 145,
#  'modules': 146,
#  'fundamentals': 147,
#  'libraries': 148,
#  'analysis': 149,
#  'sql': 150,
#  'maths': 151,
#  'machine': 152,
#  'algorithms': 153,
#  'practical': 154,
#  'mlops': 155,
#  'check': 156,
#  'detailed': 157,
#  'courses': 158,
#  '637339afe4b0615a1bbed390': 159,
#  'both': 160,
#  'program’s': 161,
#  'curriculum': 162,
#  'recorded': 163,
#  'even': 164,
#  'go': 165,
#  'back': 166,
#  'find': 167,
#  'schedule': 168,
#  'checkout': 169,
#  'sheet': 170,
#  'table': 171,
#  'docs': 172,
#  'spreadsheets': 173,
#  'd': 174,
#  '16ootax': 175,
#  'a6oraecg4emgexhqqpv3noqpyku7rj6arozk': 176,
#  'edit': 177,
#  'usp': 178,
#  'sharing': 179,
#  'roughly': 180,
#  'last': 181,
#  'hours': 182,
#  'language': 183,
#  'spoken': 184,
#  'instructor': 185,
#  'during': 186,
#  'hinglish': 187,
#  'informed': 188,
#  'upcoming': 189,
#  'side': 190,
#  'before': 191,
#  'every': 192,
#  'become': 193,
#  'user': 194,
#  'non': 195,
#  'tech': 196,
#  'background': 197,
#  'lectures': 198,
#  'content': 199,
#  'provide': 200,
#  'with': 201,
#  'solutions': 202,
#  'self': 203,
#  'evaluate': 204,
#  'yourself': 205,
#  'questions': 206,
#  'youtube': 207,
#  'channel': 208,
#  'amount': 209,
#  'unfortunately': 210,
#  'then': 211,
#  '1st': 212,
#  '30': 213,
#  'essentially': 214,
#  'wait': 215,
#  'end': 216,
#  'like': 217,
#  'making': 218,
#  'policy': 219,
#  'made': 220,
#  'post': 221,
#  'when': 222,
#  'view': 223,
#  'one': 224,
#  'tricky': 225,
#  'carefully': 226,
#  'valid': 227,
#  'purchased': 228,
#  '20th': 229,
#  'purchase': 230,
#  'over': 231,
#  'installments': 232,
#  'aug': 233,
#  '2024': 234,
#  'why': 235,
#  'lifetime': 236,
#  'because': 237,
#  'low': 238,
#  'reach': 239,
#  'out': 240,
#  'fill': 241,
#  'team': 242,
#  'still': 243,
#  'ask': 244,
#  'doubts': 245,
#  'just': 246,
#  'select': 247,
#  'gmai': 248,
#  'criteria': 249,
#  'there': 250,
#  'criterias': 251,
#  'attempt': 252,
#  'assessments': 253,
#  'joining': 254,
#  'current': 255,
#  'that': 256,
#  'comes': 257,
#  'under': 258}

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[91, 1],
#  [91, 1, 12],
#  [11, 8],
#  [11, 8, 1],
#  [11, 8, 1, 13],
#  [11, 8, 1, 13, 39],
#  [11, 8, 1, 13, 39, 16],
#  [11, 8, 1, 13, 39, 16, 40],
#  [11, 8, 1, 13, 39, 16, 40, 49],
#  [11, 8, 1, 13, 39, 16, 40, 49, 64],
#  [11, 8, 1, 13, 39, 16, 40, 49, 64, 12],
#  [11, 8, 1, 13, 39, 16, 40, 49, 64, 12, 140],
#  [11, 8, 1, 13, 39, 16, 40, 49, 64, 12, 140, 141],
#  [1, 13],
#  [1, 13, 92],
#  [1, 13, 92, 5],
#  [1, 13, 92, 5, 41],
#  [1, 13, 92, 5, 41, 26],
#  [1, 13, 92, 5, 41, 26, 93],
#  [1, 13, 92, 5, 41, 26, 93, 27],
#  [1, 13, 92, 5, 41, 26, 93, 27, 2],
#  [1, 13, 92, 5, 41, 26, 93, 27, 2, 7],
#  [1, 13, 92, 5, 41, 26, 93, 27, 2, 7, 4],
#  [1, 13, 92, 5, 41, 26, 93, 27, 2, 7, 4, 21],
#  [1, 13, 92, 5, 41, 26, 93, 27, 2, 7, 4, 21, 41],
#  [1, 13, 92, 5, 41, 26, 93, 27, 2, 7, 4, 21, 41, 65],
#  [1, 13, 92, 5, 41, 26, 93, 27, 2, 7, 4, 21, 41, 65, 6],
#  [1, 13, 92, 5, 41, 26, 93, 27, 2, 7, 4, 21, 41, 65, 6, 28],
#  [1, 13, 92, 5, 41, 26, 93, 27, 2, 7, 4, 21, 41, 65, 6, 28, 66],
#  [1, 13, 92, 5, 41, 26, 93, 27, 2, 7, 4, 21, 41, 65, 6, 28, 66, 42],
#  [11, 8],
#  [11, 8, 1],
#  [11, 8, 1, 67],
#  [11, 8, 1, 67, 68],
#  [11, 8, 1, 67, 68, 6],
#  [11, 8, 1, 67, 68, 6, 1],
#  [11, 8, 1, 67, 68, 6, 1, 13],
#  [1, 67],
#  [1, 67, 68],
#  [1, 67, 68, 6],
#  [1, 67, 68, 6, 1],
#  [1, 67, 68, 6, 1, 13],
#  [1, 67, 68, 6, 1, 13, 8],
#  [1, 67, 68, 6, 1, 13, 8, 50],
#  [1, 67, 68, 6, 1, 13, 8, 50, 69],
#  [1, 67, 68, 6, 1, 13, 8, 50, 69, 51],
#  [1, 67, 68, 6, 1, 13, 8, 50, 69, 51, 1],
#  [1, 67, 68, 6, 1, 13, 8, 50, 69, 51, 1, 67],
#  [1, 67, 68, 6, 1, 13, 8, 50, 69, 51, 1, 67, 13],
#  [1, 67, 68, 6, 1, 13, 8, 50, 69, 51, 1, 67, 13, 39],
#  [1, 67, 68, 6, 1, 13, 8, 50, 69, 51, 1, 67, 13, 39, 142],
#  [1, 67, 68, 6, 1, 13, 8, 50, 69, 51, 1, 67, 13, 39, 142, 66],
#  [1, 67, 68, 6, 1, 13, 8, 50, 69, 51, 1, 67, 13, 39, 142, 66, 50],
#  [1, 67, 68, 6, 1, 13, 8, 50, 69, 51, 1, 67, 13, 39, 142, 66, 50, 28],
#  [1, 67, 68, 6, 1, 13, 8, 50, 69, 51, 1, 67, 13, 39, 142, 66, 50, 28, 52],
#  [1, 67, 68, 6, 1, 13, 8, 50, 69, 51, 1, 67, 13, 39, 142, 66, 50, 28, 52, 143],
#  [11, 8],
#  [11, 8, 1],
#  [11, 8, 1, 94],
#  [11, 8, 1, 94, 6],
#  [11, 8, 1, 94, 6, 1],
#  [11, 8, 1, 94, 6, 1, 64],
#  [11, 8, 1, 94, 6, 1, 64, 12],
#  [29, 9],
#  [29, 9, 22],
#  [29, 9, 22, 144],
#  [29, 9, 22, 144, 1],
#  [29, 9, 22, 144, 1, 145],
#  [29, 9, 22, 144, 1, 145, 146],
#  [95, 147],
#  [95, 148],
#  [95, 148, 16],
#  [95, 148, 16, 40],
#  [95, 148, 16, 40, 49],
#  [40, 149],
#  [150, 16],
#  [150, 16, 40],
#  [150, 16, 40, 49],
#  [151, 16],
#  [151, 16, 152],
#  [151, 16, 152, 70],
#  [96, 153],
#  [154, 96],
#  [71, 97],
#  [2, 10],
#  [2, 10, 156],
#  [2, 10, 156, 1],
#  [2, 10, 156, 1, 157],
#  [2, 10, 156, 1, 157, 94],
#  [2, 10, 156, 1, 157, 94, 98],
#  [2, 10, 156, 1, 157, 94, 98, 72],
#  [2, 10, 156, 1, 157, 94, 98, 72, 99],
#  [2, 10, 156, 1, 157, 94, 98, 72, 99, 30],
#  [2, 10, 156, 1, 157, 94, 98, 72, 99, 30, 14],
#  [2, 10, 156, 1, 157, 94, 98, 72, 99, 30, 14, 158],
#  [2, 10, 156, 1, 157, 94, 98, 72, 99, 30, 14, 158, 30],
#  [2, 10, 156, 1, 157, 94, 98, 72, 99, 30, 14, 158, 30, 40],
#  [2, 10, 156, 1, 157, 94, 98, 72, 99, 30, 14, 158, 30, 40, 49],
#  [2, 10, 156, 1, 157, 94, 98, 72, 99, 30, 14, 158, 30, 40, 49, 64],
#  [2, 10, 156, 1, 157, 94, 98, 72, 99, 30, 14, 158, 30, 40, 49, 64, 12],
#  [2, 10, 156, 1, 157, 94, 98, 72, 99, 30, 14, 158, 30, 40, 49, 64, 12, 159],
#  [9, 100],
#  [9, 100, 70],
#  [9, 100, 70, 17],
#  [9, 100, 70, 17, 101],
#  [9, 100, 70, 17, 101, 22],
#  [9, 100, 70, 17, 101, 22, 5],
#  [9, 100, 70, 17, 101, 22, 5, 73],
#  [9, 100, 70, 17, 101, 22, 5, 73, 6],
#  [9, 100, 70, 17, 101, 22, 5, 73, 6, 31],
#  [9, 100, 70, 17, 101, 22, 5, 73, 6, 31, 12],
#  [102, 101],
#  [102, 101, 17],
#  [102, 101, 17, 100],
#  [102, 101, 17, 100, 70],
#  [102, 101, 17, 100, 70, 160],
#  [102, 101, 17, 100, 70, 160, 74],
#  [102, 101, 17, 100, 70, 160, 74, 53],
#  [102, 101, 17, 100, 70, 160, 74, 53, 5],
#  [102, 101, 17, 100, 70, 160, 74, 53, 5, 73],
#  [102, 101, 17, 100, 70, 160, 74, 53, 5, 73, 6],
#  [102, 101, 17, 100, 70, 160, 74, 53, 5, 73, 6, 31],
#  [102, 101, 17, 100, 70, 160, 74, 53, 5, 73, 6, 31, 161],
#  [102, 101, 17, 100, 70, 160, 74, 53, 5, 73, 6, 31, 161, 162],
#  [11, 23],
#  [11, 23, 3],
#  [11, 23, 3, 103],
#  [11, 23, 3, 103, 5],
#  [11, 23, 3, 103, 5, 104],
#  [11, 23, 3, 103, 5, 104, 32],
#  [11, 23, 3, 103, 5, 104, 32, 9],
#  [11, 23, 3, 103, 5, 104, 32, 9, 3],
#  [11, 23, 3, 103, 5, 104, 32, 9, 3, 43],
#  [11, 23, 3, 103, 5, 104, 32, 9, 3, 43, 5],
#  [11, 23, 3, 103, 5, 104, 32, 9, 3, 43, 5, 105],
#  [11, 23, 3, 103, 5, 104, 32, 9, 3, 43, 5, 105, 6],
#  [11, 23, 3, 103, 5, 104, 32, 9, 3, 43, 5, 105, 6, 1],
#  [11, 23, 3, 103, 5, 104, 32, 9, 3, 43, 5, 105, 6, 1, 32],
#  [44, 15],
#  [44, 15, 33],
#  [44, 15, 33, 34],
#  [44, 15, 33, 34, 74],
#  [44, 15, 33, 34, 74, 163],
#  [44, 15, 33, 34, 74, 163, 51],
#  [44, 15, 33, 34, 74, 163, 51, 164],
#  [44, 15, 33, 34, 74, 163, 51, 164, 23],
#  [44, 15, 33, 34, 74, 163, 51, 164, 23, 2],
#  [44, 15, 33, 34, 74, 163, 51, 164, 23, 2, 103],
#  [44, 15, 33, 34, 74, 163, 51, 164, 23, 2, 103, 5],
#  [44, 15, 33, 34, 74, 163, 51, 164, 23, 2, 103, 5, 32],
#  [44, 15, 33, 34, 74, 163, 51, 164, 23, 2, 103, 5, 32, 2],
#  [44, 15, 33, 34, 74, 163, 51, 164, 23, 2, 103, 5, 32, 2, 10],
#  [44, 15, 33, 34, 74, 163, 51, 164, 23, 2, 103, 5, 32, 2, 10, 165],
#  [44, 15, 33, 34, 74, 163, 51, 164, 23, 2, 103, 5, 32, 2, 10, 165, 166],
#  [44, 15, 33, 34, 74, 163, 51, 164, 23, 2, 103, 5, 32, 2, 10, 165, 166, 17],
#  [44,
#   15,
#   33,
#   34,
#   74,
#   163,
#   51,
#   164,
#   23,
#   2,
#   103,
#   5,
#   32,
#   2,
#   10,
#   165,
#   166,
#   17,
#   54],
#  [44,
#   15,
#   33,
#   34,
#   74,
#   163,
#   51,
#   164,
#   23,
#   2,
#   103,
#   5,
#   32,
#   2,
#   10,
#   165,
#   166,
#   17,
#   54,
#   1],
#  [44,
#   15,
#   33,
#   34,
#   74,
#   163,
#   51,
#   164,
#   23,
#   2,
#   103,
#   5,
#   32,
#   2,
#   10,
#   165,
#   166,
#   17,
#   54,
#   1,
#   105],
#  [27, 10],
#  [27, 10, 3],
#  [27, 10, 3, 167],
#  [27, 10, 3, 167, 1],
#  [27, 10, 3, 167, 1, 106],
#  [27, 10, 3, 167, 1, 106, 168],
#  [169, 31],
#  [169, 31, 55],
#  [169, 31, 55, 170],
#  [169, 31, 55, 170, 4],
#  [169, 31, 55, 170, 4, 75],
#  [169, 31, 55, 170, 4, 75, 42],
#  [169, 31, 55, 170, 4, 75, 42, 56],
#  [169, 31, 55, 170, 4, 75, 42, 56, 42],
#  [169, 31, 55, 170, 4, 75, 42, 56, 42, 107],
#  [169, 31, 55, 170, 4, 75, 42, 56, 42, 107, 171],
#  [169, 31, 55, 170, 4, 75, 42, 56, 42, 107, 171, 6],
#  [169, 31, 55, 170, 4, 75, 42, 56, 42, 107, 171, 6, 1],
#  [169, 31, 55, 170, 4, 75, 42, 56, 42, 107, 171, 6, 1, 13],
#  [169, 31, 55, 170, 4, 75, 42, 56, 42, 107, 171, 6, 1, 13, 72],
#  [169, 31, 55, 170, 4, 75, 42, 56, 42, 107, 171, 6, 1, 13, 72, 172],
#  [169, 31, 55, 170, 4, 75, 42, 56, 42, 107, 171, 6, 1, 13, 72, 172, 55],
#  [169, 31, 55, 170, 4, 75, 42, 56, 42, 107, 171, 6, 1, 13, 72, 172, 55, 57],
#  [169,
#   31,
#   55,
#   170,
#   4,
#   75,
#   42,
#   56,
#   42,
#   107,
#   171,
#   6,
#   1,
#   13,
#   72,
#   172,
#   55,
#   57,
#   173],
#  [169,
#   31,
#   55,
#   170,
#   4,
#   75,
#   42,
#   56,
#   42,
#   107,
#   171,
#   6,
#   1,
#   13,
#   72,
#   172,
#   55,
#   57,
#   173,
#   174],
#  [169,
#   31,
#   55,
#   170,
#   4,
#   75,
#   42,
#   56,
#   42,
#   107,
#   171,
#   6,
#   1,
#   13,
#   72,
#   172,
#   55,
#   57,
#   173,
#   174,
#   175],
#  [169,
#   31,
#   55,
#   170,
#   4,
#   75,
#   42,
#   56,
#   42,
#   107,
#   171,
#   6,
#   1,
#   13,
#   72,
#   172,
#   55,
#   57,
#   173,
#   174,
#   175,
#   176],
#  [169,
#   31,
#   55,
#   170,
#   4,
#   75,
#   42,
#   56,
#   42,
#   107,
#   171,
#   6,
#   1,
#   13,
#   72,
#   172,
#   55,
#   57,
#   173,
#   174,
#   175,
#   176,
#   177],
#  [169,
#   31,
#   55,
#   170,
#   4,
#   75,
#   42,
#   56,
#   42,
#   107,
#   171,
#   6,
#   1,
#   13,
#   72,
#   172,
#   55,
#   57,
#   173,
#   174,
#   175,
#   176,
#   177,
#   178],
#  [169,
#   31,
#   55,
#   170,
#   4,
#   75,
#   42,
#   56,
#   42,
#   107,
#   171,
#   6,
#   1,
#   13,
#   72,
#   172,
#   55,
#   57,
#   173,
#   174,
#   175,
#   176,
#   177,
#   178,
#   179],
#  [11, 8],
#  [11, 8, 1],
#  [11, 8, 1, 107],
#  [11, 8, 1, 107, 68],
#  [11, 8, 1, 107, 68, 6],
#  [11, 8, 1, 107, 68, 6, 15],
#  [11, 8, 1, 107, 68, 6, 15, 1],
#  [11, 8, 1, 107, 68, 6, 15, 1, 104],
#  [11, 8, 1, 107, 68, 6, 15, 1, 104, 34],
#  [180, 15],
#  [180, 15, 1],
#  [180, 15, 1, 34],
#  [180, 15, 1, 34, 181],
#  [180, 15, 1, 34, 181, 108],
#  [180, 15, 1, 34, 181, 108, 182],
#  [11, 8],
#  [11, 8, 1],
#  [11, 8, 1, 183],
#  [11, 8, 1, 183, 184],
#  [11, 8, 1, 183, 184, 56],
#  [11, 8, 1, 183, 184, 56, 1],
#  [11, 8, 1, 183, 184, 56, 1, 185],
#  [11, 8, 1, 183, 184, 56, 1, 185, 186],
#  [11, 8, 1, 183, 184, 56, 1, 185, 186, 1],
#  [11, 8, 1, 183, 184, 56, 1, 185, 186, 1, 34],
#  [109, 9],
#  [109, 9, 3],
#  [109, 9, 3, 22],
#  [109, 9, 3, 22, 188],
#  [109, 9, 3, 22, 188, 91],
#  [109, 9, 3, 22, 188, 91, 1],
#  [109, 9, 3, 22, 188, 91, 1, 189],
#  [109, 9, 3, 22, 188, 91, 1, 189, 106],
#  [2, 9],
#  [2, 9, 43],
#  [2, 9, 43, 5],
#  [2, 9, 43, 5, 58],
#  [2, 9, 43, 5, 58, 59],
#  [2, 9, 43, 5, 58, 59, 33],
#  [2, 9, 43, 5, 58, 59, 33, 190],
#  [2, 9, 43, 5, 58, 59, 33, 190, 191],
#  [2, 9, 43, 5, 58, 59, 33, 190, 191, 192],
#  [2, 9, 43, 5, 58, 59, 33, 190, 191, 192, 35],
#  [2, 9, 43, 5, 58, 59, 33, 190, 191, 192, 35, 32],
#  [2, 9, 43, 5, 58, 59, 33, 190, 191, 192, 35, 32, 45],
#  [2, 9, 43, 5, 58, 59, 33, 190, 191, 192, 35, 32, 45, 2],
#  [2, 9, 43, 5, 58, 59, 33, 190, 191, 192, 35, 32, 45, 2, 193],
#  [2, 9, 43, 5, 58, 59, 33, 190, 191, 192, 35, 32, 45, 2, 193, 5],
#  [2, 9, 43, 5, 58, 59, 33, 190, 191, 192, 35, 32, 45, 2, 193, 5, 35],
#  [2, 9, 43, 5, 58, 59, 33, 190, 191, 192, 35, 32, 45, 2, 193, 5, 35, 194],
#  [10, 3],
#  [10, 3, 24],
#  [10, 3, 24, 31],
#  [10, 3, 24, 31, 13],
#  [10, 3, 24, 31, 13, 23],
#  [10, 3, 24, 31, 13, 23, 3],
#  [10, 3, 24, 31, 13, 23, 3, 25],
#  [10, 3, 24, 31, 13, 23, 3, 25, 59],
#  [10, 3, 24, 31, 13, 23, 3, 25, 59, 5],
#  [10, 3, 24, 31, 13, 23, 3, 25, 59, 5, 195],
#  [10, 3, 24, 31, 13, 23, 3, 25, 59, 5, 195, 196],
#  [10, 3, 24, 31, 13, 23, 3, 25, 59, 5, 195, 196, 197],
#  [44, 110],
#  [3, 25],
#  [3, 25, 76],
#  [3, 25, 76, 10],
#  [3, 25, 76, 10, 3],
#  [3, 25, 76, 10, 3, 46],
#  [3, 25, 76, 10, 3, 46, 1],
#  [3, 25, 76, 10, 3, 46, 1, 12],
#  [3, 25, 76, 10, 3, 46, 1, 12, 14],
#  [3, 25, 76, 10, 3, 46, 1, 12, 14, 1],
#  [3, 25, 76, 10, 3, 46, 1, 12, 14, 1, 111],
#  [110, 2],
#  [110, 2, 10],
#  [110, 2, 10, 46],
#  [110, 2, 10, 46, 1],
#  [110, 2, 10, 46, 1, 12],
#  [110, 2, 10, 46, 1, 12, 112],
#  [23, 3],
#  [23, 3, 46],
#  [23, 3, 46, 18],
#  [23, 3, 46, 18, 14],
#  [23, 3, 46, 18, 14, 1],
#  [23, 3, 46, 18, 14, 1, 111],
#  [23, 3, 46, 18, 14, 1, 111, 9],
#  [23, 3, 46, 18, 14, 1, 111, 9, 3],
#  [23, 3, 46, 18, 14, 1, 111, 9, 3, 22],
#  [23, 3, 46, 18, 14, 1, 111, 9, 3, 22, 36],
#  [23, 3, 46, 18, 14, 1, 111, 9, 3, 22, 36, 4],
#  [23, 3, 46, 18, 14, 1, 111, 9, 3, 22, 36, 4, 75],
#  [23, 3, 46, 18, 14, 1, 111, 9, 3, 22, 36, 4, 75, 15],
#  [23, 3, 46, 18, 14, 1, 111, 9, 3, 22, 36, 4, 75, 15, 1],
#  [23, 3, 46, 18, 14, 1, 111, 9, 3, 22, 36, 4, 75, 15, 1, 47],
#  [23, 3, 46, 18, 14, 1, 111, 9, 3, 22, 36, 4, 75, 15, 1, 47, 198],
#  [44, 45],
#  [44, 45, 2],
#  [44, 45, 2, 21],
#  [44, 45, 2, 21, 1],
#  [44, 45, 2, 21, 1, 19],
#  [44, 45, 2, 21, 1, 19, 2],
#  [44, 45, 2, 21, 1, 19, 2, 9],
#  [44, 45, 2, 21, 1, 19, 2, 9, 22],
#  [44, 45, 2, 21, 1, 19, 2, 9, 22, 36],
#  [44, 45, 2, 21, 1, 19, 2, 9, 22, 36, 4],
#  [44, 45, 2, 21, 1, 19, 2, 9, 22, 36, 4, 75],
#  [44, 45, 2, 21, 1, 19, 2, 9, 22, 36, 4, 75, 15],
#  [44, 45, 2, 21, 1, 19, 2, 9, 22, 36, 4, 75, 15, 1],
#  [44, 45, 2, 21, 1, 19, 2, 9, 22, 36, 4, 75, 15, 1, 47],
#  [44, 45, 2, 21, 1, 19, 2, 9, 22, 36, 4, 75, 15, 1, 47, 199],
#  [44, 45, 2, 21, 1, 19, 2, 9, 22, 36, 4, 75, 15, 1, 47, 199, 14],
#  [44, 45, 2, 21, 1, 19, 2, 9, 22, 36, 4, 75, 15, 1, 47, 199, 14, 37],
#  [44, 45, 2, 21, 1, 19, 2, 9, 22, 36, 4, 75, 15, 1, 47, 199, 14, 37, 77],
#  [27, 24],
#  [27, 24, 3],
#  [27, 24, 3, 7],
#  [27, 24, 3, 7, 4],
#  [27, 24, 3, 7, 4, 113],
#  [27, 24, 3, 7, 4, 113, 1],
#  [27, 24, 3, 7, 4, 113, 1, 78],
#  [2, 79],
#  [2, 79, 7],
#  [2, 79, 7, 4],
#  [2, 79, 7, 4, 113],
#  [2, 79, 7, 4, 113, 1],
#  [2, 79, 7, 4, 113, 1, 78],
#  [2, 79, 7, 4, 113, 1, 78, 29],
#  [2, 79, 7, 4, 113, 1, 78, 29, 9],
#  [2, 79, 7, 4, 113, 1, 78, 29, 9, 200],
#  [2, 79, 7, 4, 113, 1, 78, 29, 9, 200, 2],
#  [2, 79, 7, 4, 113, 1, 78, 29, 9, 200, 2, 201],
#  [2, 79, 7, 4, 113, 1, 78, 29, 9, 200, 2, 201, 1],
#  [2, 79, 7, 4, 113, 1, 78, 29, 9, 200, 2, 201, 1, 202],
#  [2, 79, 7, 4, 113, 1, 78, 29, 9, 200, 2, 201, 1, 202, 2],
#  [2, 79, 7, 4, 113, 1, 78, 29, 9, 200, 2, 201, 1, 202, 2, 7],
#  [2, 79, 7, 4, 113, 1, 78, 29, 9, 200, 2, 201, 1, 202, 2, 7, 4],
#  [2, 79, 7, 4, 113, 1, 78, 29, 9, 200, 2, 201, 1, 202, 2, 7, 4, 203],
#  [2, 79, 7, 4, 113, 1, 78, 29, 9, 200, 2, 201, 1, 202, 2, 7, 4, 203, 204],
#  [2, 79, 7, 4, 113, 1, 78, 29, 9, 200, 2, 201, 1, 202, 2, 7, 4, 203, 204, 1],
#  [2,
#   79,
#   7,
#   4,
#   113,
#   1,
#   78,
#   29,
#   9,
#   200,
#   2,
#   201,
#   1,
#   202,
#   2,
#   7,
#   4,
#   203,
#   204,
#   1,
#   78],
#  [2,
#   79,
#   7,
#   4,
#   113,
#   1,
#   78,
#   29,
#   9,
#   200,
#   2,
#   201,
#   1,
#   202,
#   2,
#   7,
#   4,
#   203,
#   204,
#   1,
#   78,
#   205],
#  [9, 29],
#  [9, 29, 24],
#  [9, 29, 24, 71],
#  [9, 29, 24, 71, 97],
#  [9, 29, 24, 71, 97, 14],
#  [9, 29, 24, 71, 97, 14, 1],
#  [9, 29, 24, 71, 97, 14, 1, 12],
#  [27, 10],
#  [27, 10, 29],
#  [27, 10, 29, 60],
#  [27, 10, 29, 60, 2],
#  [2, 10],
#  [2, 10, 58],
#  [2, 10, 58, 61],
#  [2, 10, 58, 61, 62],
#  [2, 10, 58, 61, 62, 80],
#  [2, 10, 58, 61, 62, 80, 30],
#  [2, 10, 58, 61, 62, 80, 30, 114],
#  [2, 10, 58, 61, 62, 80, 30, 114, 57],
#  [19, 115],
#  [19, 115, 116],
#  [19, 115, 116, 206],
#  [27, 24],
#  [27, 24, 29],
#  [27, 24, 29, 7],
#  [27, 24, 29, 7, 4],
#  [27, 24, 29, 7, 4, 21],
#  [27, 24, 29, 7, 4, 21, 33],
#  [27, 24, 29, 7, 4, 21, 33, 65],
#  [27, 24, 29, 7, 4, 21, 33, 65, 37],
#  [27, 24, 29, 7, 4, 21, 33, 65, 37, 207],
#  [27, 24, 29, 7, 4, 21, 33, 65, 37, 207, 208],
#  [27, 24, 29, 7, 4, 21, 33, 65, 37, 207, 208, 81],
#  [27, 24, 29, 7, 4, 21, 33, 65, 37, 207, 208, 81, 38],
#  [2, 7],
#  [2, 7, 4],
#  [2, 7, 4, 21],
#  [2, 7, 4, 21, 15],
#  [2, 7, 4, 21, 15, 37],
#  [2, 7, 4, 21, 15, 37, 41],
#  [2, 7, 4, 21, 15, 37, 41, 65],
#  [2, 7, 4, 21, 15, 37, 41, 65, 20],
#  [2, 7, 4, 21, 15, 37, 41, 65, 20, 33],
#  [2, 7, 4, 21, 15, 37, 41, 65, 20, 33, 38],
#  [2, 7, 4, 21, 15, 37, 41, 65, 20, 33, 38, 98],
#  [2, 7, 4, 21, 15, 37, 41, 65, 20, 33, 38, 98, 8],
#  [2, 7, 4, 21, 15, 37, 41, 65, 20, 33, 38, 98, 8, 1],
#  [2, 7, 4, 21, 15, 37, 41, 65, 20, 33, 38, 98, 8, 1, 117],
#  [2, 7, 4, 21, 15, 37, 41, 65, 20, 33, 38, 98, 8, 1, 117, 16],
#  [2, 7, 4, 21, 15, 37, 41, 65, 20, 33, 38, 98, 8, 1, 117, 16, 33],
#  [2, 7, 4, 21, 15, 37, 41, 65, 20, 33, 38, 98, 8, 1, 117, 16, 33, 38],
#  [2, 7, 4, 21, 15, 37, 41, 65, 20, 33, 38, 98, 8, 1, 117, 16, 33, 38, 72],
#  [2, 7, 4, 21, 15, 37, 41, 65, 20, 33, 38, 98, 8, 1, 117, 16, 33, 38, 72, 99],
#  [2,
#   7,
#   4,
#   21,
#   15,
#   37,
#   41,
#   65,
#   20,
#   33,
#   38,
#   98,
#   8,
#   1,
#   117,
#   16,
#   33,
#   38,
#   72,
#   99,
#   30],
#  [2,
#   7,
#   4,
#   21,
#   15,
#   37,
#   41,
#   65,
#   20,
#   33,
#   38,
#   98,
#   8,
#   1,
#   117,
#   16,
#   33,
#   38,
#   72,
#   99,
#   30,
#   14],
#  [10, 29],
#  [10, 29, 18],
#  [10, 29, 18, 1],
#  [10, 29, 18, 1, 118],
#  [10, 29, 18, 1, 118, 209],
#  [10, 29, 18, 1, 118, 209, 6],
#  [10, 29, 18, 1, 118, 209, 6, 28],
#  [10, 29, 18, 1, 118, 209, 6, 28, 52],
#  [10, 29, 18, 1, 118, 209, 6, 28, 52, 15],
#  [10, 29, 18, 1, 118, 209, 6, 28, 52, 15, 62],
#  [10, 29, 18, 1, 118, 209, 6, 28, 52, 15, 62, 45],
#  [210, 102],
#  [210, 102, 1],
#  [210, 102, 1, 12],
#  [210, 102, 1, 12, 92],
#  [210, 102, 1, 12, 92, 5],
#  [210, 102, 1, 12, 92, 5, 41],
#  [210, 102, 1, 12, 92, 5, 41, 26],
#  [210, 102, 1, 12, 92, 5, 41, 26, 93],
#  [11, 8],
#  [11, 8, 1],
#  [11, 8, 1, 82],
#  [11, 8, 1, 82, 6],
#  [11, 8, 1, 82, 6, 41],
#  [11, 8, 1, 82, 6, 41, 26],
#  [11, 8, 1, 82, 6, 41, 26, 119],
#  [11, 8, 1, 82, 6, 41, 26, 119, 23],
#  [11, 8, 1, 82, 6, 41, 26, 119, 23, 3],
#  [11, 8, 1, 82, 6, 41, 26, 119, 23, 3, 18],
#  [11, 8, 1, 82, 6, 41, 26, 119, 23, 3, 18, 20],
#  [11, 8, 1, 82, 6, 41, 26, 119, 23, 3, 18, 20, 83],
#  [11, 8, 1, 82, 6, 41, 26, 119, 23, 3, 18, 20, 83, 84],
#  [11, 8, 1, 82, 6, 41, 26, 119, 23, 3, 18, 20, 83, 84, 211],
#  [11, 8, 1, 82, 6, 41, 26, 119, 23, 3, 18, 20, 83, 84, 211, 24],
#  [11, 8, 1, 82, 6, 41, 26, 119, 23, 3, 18, 20, 83, 84, 211, 24, 3],
#  [11, 8, 1, 82, 6, 41, 26, 119, 23, 3, 18, 20, 83, 84, 211, 24, 3, 7],
#  [11, 8, 1, 82, 6, 41, 26, 119, 23, 3, 18, 20, 83, 84, 211, 24, 3, 7, 4],
#  [11, 8, 1, 82, 6, 41, 26, 119, 23, 3, 18, 20, 83, 84, 211, 24, 3, 7, 4, 18],
#  [11,
#   8,
#   1,
#   82,
#   6,
#   41,
#   26,
#   119,
#   23,
#   3,
#   18,
#   20,
#   83,
#   84,
#   211,
#   24,
#   3,
#   7,
#   4,
#   18,
#   120],
#  [11,
#   8,
#   1,
#   82,
#   6,
#   41,
#   26,
#   119,
#   23,
#   3,
#   18,
#   20,
#   83,
#   84,
#   211,
#   24,
#   3,
#   7,
#   4,
#   18,
#   120,
#   20],
#  [11,
#   8,
#   1,
#   82,
#   6,
#   41,
#   26,
#   119,
#   23,
#   3,
#   18,
#   20,
#   83,
#   84,
#   211,
#   24,
#   3,
#   7,
#   4,
#   18,
#   120,
#   20,
#   212],
#  [11,
#   8,
#   1,
#   82,
#   6,
#   41,
#   26,
#   119,
#   23,
#   3,
#   18,
#   20,
#   83,
#   84,
#   211,
#   24,
#   3,
#   7,
#   4,
#   18,
#   120,
#   20,
#   212,
#   48],
#  [11,
#   8,
#   1,
#   82,
#   6,
#   41,
#   26,
#   119,
#   23,
#   3,
#   18,
#   20,
#   83,
#   84,
#   211,
#   24,
#   3,
#   7,
#   4,
#   18,
#   120,
#   20,
#   212,
#   48,
#   81],
#  [11,
#   8,
#   1,
#   82,
#   6,
#   41,
#   26,
#   119,
#   23,
#   3,
#   18,
#   20,
#   83,
#   84,
#   211,
#   24,
#   3,
#   7,
#   4,
#   18,
#   120,
#   20,
#   212,
#   48,
#   81,
#   83],
#  [11,
#   8,
#   1,
#   82,
#   6,
#   41,
#   26,
#   119,
#   23,
#   3,
#   18,
#   20,
#   83,
#   84,
#   211,
#   24,
#   3,
#   7,
#   4,
#   18,
#   120,
#   20,
#   212,
#   48,
#   81,
#   83,
#   48],
#  [83, 48],
#  [83, 48, 1],
#  [83, 48, 1, 82],
#  [83, 48, 1, 82, 85],
#  [83, 48, 1, 82, 85, 8],
#  [83, 48, 1, 82, 85, 8, 213],
#  [83, 48, 1, 82, 85, 8, 213, 121],
#  [83, 48, 1, 82, 85, 8, 213, 121, 59],
#  [83, 48, 1, 82, 85, 8, 213, 121, 59, 1],
#  [83, 48, 1, 82, 85, 8, 213, 121, 59, 1, 122],
#  [83, 48, 1, 82, 85, 8, 213, 121, 59, 1, 122, 2],
#  [83, 48, 1, 82, 85, 8, 213, 121, 59, 1, 122, 2, 21],
#  [83, 48, 1, 82, 85, 8, 213, 121, 59, 1, 122, 2, 21, 1],
#  [83, 48, 1, 82, 85, 8, 213, 121, 59, 1, 122, 2, 21, 1, 19],
#  [83, 48, 1, 82, 85, 8, 213, 121, 59, 1, 122, 2, 21, 1, 19, 51],
#  [83, 48, 1, 82, 85, 8, 213, 121, 59, 1, 122, 2, 21, 1, 19, 51, 214],
#  [83, 48, 1, 82, 85, 8, 213, 121, 59, 1, 122, 2, 21, 1, 19, 51, 214, 2],
#  [83, 48, 1, 82, 85, 8, 213, 121, 59, 1, 122, 2, 21, 1, 19, 51, 214, 2, 10],
#  [83,
#   48,
#   1,
#   82,
#   85,
#   8,
#   213,
#   121,
#   59,
#   1,
#   122,
#   2,
#   21,
#   1,
#   19,
#   51,
#   214,
#   2,
#   10,
#   46],
#  [83,
#   48,
#   1,
#   82,
#   85,
#   8,
#   213,
#   121,
#   59,
#   1,
#   122,
#   2,
#   21,
#   1,
#   19,
#   51,
#   214,
#   2,
#   10,
#   46,
#   112],
#  [83,
#   48,
#   1,
#   82,
#   85,
#   8,
#   213,
#   121,
#   59,
#   1,
#   122,
#   2,
#   21,
#   1,
#   19,
#   51,
#   214,
#   2,
#   10,
#   46,
#   112,
#   2],
#  [83,
#   48,
#   1,
#   82,
#   85,
#   8,
#   213,
#   121,
#   59,
#   1,
#   122,
#   2,
#   21,
#   1,
#   19,
#   51,
#   214,
#   2,
#   10,
#   46,
#   112,
#   2,
#   79],
#  [83,
#   48,
#   1,
#   82,
#   85,
#   8,
#   213,
#   121,
#   59,
#   1,
#   122,
#   2,
#   21,
#   1,
#   19,
#   51,
#   214,
#   2,
#   10,
#   46,
#   112,
#   2,
#   79,
#   7],
#  [83,
#   48,
#   1,
#   82,
#   85,
#   8,
#   213,
#   121,
#   59,
#   1,
#   122,
#   2,
#   21,
#   1,
#   19,
#   51,
#   214,
#   2,
#   10,
#   46,
#   112,
#   2,
#   79,
#   7,
#   4],
#  [83,
#   48,
#   1,
#   82,
#   85,
#   8,
#   213,
#   121,
#   59,
#   1,
#   122,
#   2,
#   21,
#   1,
#   19,
#   51,
#   214,
#   2,
#   10,
#   46,
#   112,
#   2,
#   79,
#   7,
#   4,
#   215],
#  [83,
#   48,
#   1,
#   82,
#   85,
#   8,
#   213,
#   121,
#   59,
#   1,
#   122,
#   2,
#   21,
#   1,
#   19,
#   51,
#   214,
#   2,
#   10,
#   46,
#   112,
#   2,
#   79,
#   7,
#   4,
#   215,
#   16],
#  [83,
#   48,
#   1,
#   82,
#   85,
#   8,
#   213,
#   121,
#   59,
#   1,
#   122,
#   2,
#   21,
#   1,
#   19,
#   51,
#   214,
#   2,
#   10,
#   46,
#   112,
#   2,
#   79,
#   7,
#   4,
#   215,
#   16,
#   5],
#  [83,
#   48,
#   1,
#   82,
#   85,
#   8,
#   213,
#   121,
#   59,
#   1,
#   122,
#   2,
#   21,
#   1,
#   19,
#   51,
#   214,
#   2,
#   10,
#   46,
#   112,
#   2,
#   79,
#   7,
#   4,
#   215,
#   16,
#   5,
#   42],
#  [83,
#   48,
#   1,
#   82,
#   85,
#   8,
#   213,
#   121,
#   59,
#   1,
#   122,
#   2,
#   21,
#   1,
#   19,
#   51,
#   214,
#   2,
#   10,
#   46,
#   112,
#   2,
#   79,
#   7,
#   4,
#   215,
#   16,
#   5,
#   42,
#   4],
#  [83,
#   48,
#   1,
#   82,
#   85,
#   8,
#   213,
#   121,
#   59,
#   1,
#   122,
#   2,
#   21,
#   1,
#   19,
#   51,
#   214,
#   2,
#   10,
#   46,
#   112,
#   2,
#   79,
#   7,
#   4,
#   215,
#   16,
#   5,
#   42,
#   4,
#   216],
#  [11, 23],
#  [11, 23, 3],
#  [11, 23, 3, 79],
#  [11, 23, 3, 79, 217],
#  [11, 23, 3, 79, 217, 1],
#  [11, 23, 3, 79, 217, 1, 13],
#  [11, 23, 3, 79, 217, 1, 13, 86],
#  [11, 23, 3, 79, 217, 1, 13, 86, 218],
#  [11, 23, 3, 79, 217, 1, 13, 86, 218, 1],
#  [11, 23, 3, 79, 217, 1, 13, 86, 218, 1, 19],
#  [11, 23, 3, 79, 217, 1, 13, 86, 218, 1, 19, 11],
#  [11, 23, 3, 79, 217, 1, 13, 86, 218, 1, 19, 11, 8],
#  [11, 23, 3, 79, 217, 1, 13, 86, 218, 1, 19, 11, 8, 1],
#  [11, 23, 3, 79, 217, 1, 13, 86, 218, 1, 19, 11, 8, 1, 123],
#  [11, 23, 3, 79, 217, 1, 13, 86, 218, 1, 19, 11, 8, 1, 123, 219],
#  [2, 43],
#  [2, 43, 5],
#  [2, 43, 5, 50],
#  [2, 43, 5, 50, 121],
#  [2, 43, 5, 50, 121, 123],
#  [2, 43, 5, 50, 121, 123, 85],
#  [2, 43, 5, 50, 121, 123, 85, 59],
#  [2, 43, 5, 50, 121, 123, 85, 59, 1],
#  [2, 43, 5, 50, 121, 123, 85, 59, 1, 122],
#  [2, 43, 5, 50, 121, 123, 85, 59, 1, 122, 2],
#  [2, 43, 5, 50, 121, 123, 85, 59, 1, 122, 2, 7],
#  [2, 43, 5, 50, 121, 123, 85, 59, 1, 122, 2, 7, 220],
#  [2, 43, 5, 50, 121, 123, 85, 59, 1, 122, 2, 7, 220, 1],
#  [2, 43, 5, 50, 121, 123, 85, 59, 1, 122, 2, 7, 220, 1, 19],
#  [3, 25],
#  [3, 25, 124],
#  [3, 25, 124, 125],
#  [3, 25, 124, 125, 126],
#  [3, 25, 124, 125, 126, 17],
#  [3, 25, 124, 125, 126, 17, 3],
#  [3, 25, 124, 125, 126, 17, 3, 25],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1, 19],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1, 19, 20],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1, 19, 20, 1],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1, 19, 20, 1, 38],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1, 19, 20, 1, 38, 11],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1, 19, 20, 1, 38, 11, 127],
#  [3,
#   25,
#   124,
#   125,
#   126,
#   17,
#   3,
#   25,
#   53,
#   36,
#   4,
#   21,
#   1,
#   19,
#   20,
#   1,
#   38,
#   11,
#   127,
#   3],
#  [3,
#   25,
#   124,
#   125,
#   126,
#   17,
#   3,
#   25,
#   53,
#   36,
#   4,
#   21,
#   1,
#   19,
#   20,
#   1,
#   38,
#   11,
#   127,
#   3,
#   24],
#  [2, 7],
#  [2, 7, 4],
#  [2, 7, 4, 60],
#  [2, 7, 4, 60, 61],
#  [2, 7, 4, 60, 61, 56],
#  [2, 7, 4, 60, 61, 56, 128],
#  [2, 7, 4, 60, 61, 56, 128, 5],
#  [2, 7, 4, 60, 61, 56, 128, 5, 58],
#  [2, 7, 4, 60, 61, 56, 128, 5, 58, 62],
#  [2, 7, 4, 60, 61, 56, 128, 5, 58, 62, 80],
#  [2, 7, 4, 60, 61, 56, 128, 5, 58, 62, 80, 30],
#  [2, 7, 4, 60, 61, 56, 128, 5, 58, 62, 80, 30, 114],
#  [2, 7, 4, 60, 61, 56, 128, 5, 58, 62, 80, 30, 114, 57],
#  [221, 115],
#  [221, 115, 129],
#  [87, 222],
#  [87, 222, 10],
#  [87, 222, 10, 3],
#  [87, 222, 10, 3, 223],
#  [87, 222, 10, 3, 223, 1],
#  [87, 222, 10, 3, 223, 1, 35],
#  [87, 222, 10, 3, 223, 1, 35, 130],
#  [87, 222, 10, 3, 223, 1, 35, 130, 20],
#  [87, 222, 10, 3, 223, 1, 35, 130, 20, 1],
#  [87, 222, 10, 3, 223, 1, 35, 130, 20, 1, 38],
#  [31, 224],
#  [31, 224, 8],
#  [31, 224, 8, 225],
#  [31, 224, 8, 225, 51],
#  [31, 224, 8, 225, 51, 131],
#  [31, 224, 8, 225, 51, 131, 226],
#  [31, 224, 8, 225, 51, 131, 226, 2],
#  [31, 224, 8, 225, 51, 131, 226, 2, 10],
#  [31, 224, 8, 225, 51, 131, 226, 2, 10, 54],
#  [31, 224, 8, 225, 51, 131, 226, 2, 10, 54, 1],
#  [31, 224, 8, 225, 51, 131, 226, 2, 10, 54, 1, 130],
#  [31, 224, 8, 225, 51, 131, 226, 2, 10, 54, 1, 130, 87],
#  [31, 224, 8, 225, 51, 131, 226, 2, 10, 54, 1, 130, 87, 37],
#  [31, 224, 8, 225, 51, 131, 226, 2, 10, 54, 1, 130, 87, 37, 26],
#  [31, 224, 8, 225, 51, 131, 226, 2, 10, 54, 1, 130, 87, 37, 26, 8],
#  [31, 224, 8, 225, 51, 131, 226, 2, 10, 54, 1, 130, 87, 37, 26, 8, 227],
#  [31, 224, 8, 225, 51, 131, 226, 2, 10, 54, 1, 130, 87, 37, 26, 8, 227, 119],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229,
#   48],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229,
#   48,
#   132],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229,
#   48,
#   132,
#   86],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229,
#   48,
#   132,
#   86,
#   88],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229,
#   48,
#   132,
#   86,
#   88,
#   48],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229,
#   48,
#   132,
#   86,
#   88,
#   48,
#   2],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229,
#   48,
#   132,
#   86,
#   88,
#   48,
#   2,
#   9],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229,
#   48,
#   132,
#   86,
#   88,
#   48,
#   2,
#   9,
#   7],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229,
#   48,
#   132,
#   86,
#   88,
#   48,
#   2,
#   9,
#   7,
#   4],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229,
#   48,
#   132,
#   86,
#   88,
#   48,
#   2,
#   9,
#   7,
#   4,
#   230],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229,
#   48,
#   132,
#   86,
#   88,
#   48,
#   2,
#   9,
#   7,
#   4,
#   230,
#   1],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229,
#   48,
#   132,
#   86,
#   88,
#   48,
#   2,
#   9,
#   7,
#   4,
#   230,
#   1,
#   26],
#  [31,
#   224,
#   8,
#   225,
#   51,
#   131,
#   226,
#   2,
#   10,
#   54,
#   1,
#   130,
#   87,
#   37,
#   26,
#   8,
#   227,
#   119,
#   2,
#   7,
#   228,
#   26,
#   20,
#   88,
#   84,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   15,
#   1,
#   47,
#   35,
#   34,
#   14,
#   1,
#   85,
#   6,
#   88,
#   84,
#   4,
#   229,
#   48,
#   132,
#   86,
#   88,
#   48,
#   2,
#   9,
#   7,
#   4,
#   230,
#   1,
#   26,
#   120],
#  [132, 45],
#  [132, 45, 1],
#  [132, 45, 1, 13],
#  [132, 45, 1, 13, 8],
#  [132, 45, 1, 13, 8, 231],
#  [132, 45, 1, 13, 8, 231, 17],
#  [132, 45, 1, 13, 8, 231, 17, 2],
#  [132, 45, 1, 13, 8, 231, 17, 2, 7],
#  [132, 45, 1, 13, 8, 231, 17, 2, 7, 35],
#  [132, 45, 1, 13, 8, 231, 17, 2, 7, 35, 61],
#  [132, 45, 1, 13, 8, 231, 17, 2, 7, 35, 61, 28],
#  [132, 45, 1, 13, 8, 231, 17, 2, 7, 35, 61, 28, 52],
#  [132, 45, 1, 13, 8, 231, 17, 2, 7, 35, 61, 28, 52, 81],
#  [132, 45, 1, 13, 8, 231, 17, 2, 7, 35, 61, 28, 52, 81, 50],
#  [132, 45, 1, 13, 8, 231, 17, 2, 7, 35, 61, 28, 52, 81, 50, 232],
#  [132, 45, 1, 13, 8, 231, 17, 2, 7, 35, 61, 28, 52, 81, 50, 232, 6],
#  [132, 45, 1, 13, 8, 231, 17, 2, 7, 35, 61, 28, 52, 81, 50, 232, 6, 28],
#  [132, 45, 1, 13, 8, 231, 17, 2, 7, 35, 61, 28, 52, 81, 50, 232, 6, 28, 66],
#  [132, 45, 1, 13, 8, 231, 17, 2, 7, 35, 61, 28, 52, 81, 50, 232, 6, 28, 66, 2],
#  [132,
#   45,
#   1,
#   13,
#   8,
#   231,
#   17,
#   2,
#   7,
#   35,
#   61,
#   28,
#   52,
#   81,
#   50,
#   232,
#   6,
#   28,
#   66,
#   2,
#   9],
#  [132,
#   45,
#   1,
#   13,
#   8,
#   231,
#   17,
#   2,
#   7,
#   35,
#   61,
#   28,
#   52,
#   81,
#   50,
#   232,
#   6,
#   28,
#   66,
#   2,
#   9,
#   22],
#  [132,
#   45,
#   1,
#   13,
#   8,
#   231,
#   17,
#   2,
#   7,
#   35,
#   61,
#   28,
#   52,
#   81,
#   50,
#   232,
#   6,
#   28,
#   66,
#   2,
#   9,
#   22,
#   36],
#  [132,
#   45,
#   1,
#   13,
#   8,
#   231,
#   17,
#   2,
#   7,
#   35,
#   61,
#   28,
#   52,
#   81,
#   50,
#   232,
#   6,
#   28,
#   66,
#   2,
#   9,
#   22,
#   36,
#   4],
#  [132,
#   45,
#   1,
#   13,
#   8,
#   231,
#   17,
#   2,
#   7,
#   35,
#   61,
#   28,
#   52,
#   81,
#   50,
#   232,
#   6,
#   28,
#   66,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54],
#  [132,
#   45,
#   1,
#   13,
#   8,
#   231,
#   17,
#   2,
#   7,
#   35,
#   61,
#   28,
#   52,
#   81,
#   50,
#   232,
#   6,
#   28,
#   66,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   1],
#  [132,
#   45,
#   1,
#   13,
#   8,
#   231,
#   17,
#   2,
#   7,
#   35,
#   61,
#   28,
#   52,
#   81,
#   50,
#   232,
#   6,
#   28,
#   66,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   1,
#   35],
#  [132,
#   45,
#   1,
#   13,
#   8,
#   231,
#   17,
#   2,
#   7,
#   35,
#   61,
#   28,
#   52,
#   81,
#   50,
#   232,
#   6,
#   28,
#   66,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   1,
#   35,
#   34],
#  [132,
#   45,
#   1,
#   13,
#   8,
#   231,
#   17,
#   2,
#   7,
#   35,
#   61,
#   28,
#   52,
#   81,
#   50,
#   232,
#   6,
#   28,
#   66,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   1,
#   35,
#   34,
#   87],
#  [132,
#   45,
#   1,
#   13,
#   8,
#   231,
#   17,
#   2,
#   7,
#   35,
#   61,
#   28,
#   52,
#   81,
#   50,
#   232,
#   6,
#   28,
#   66,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   1,
#   35,
#   34,
#   87,
#   233],
#  [132,
#   45,
#   1,
#   13,
#   8,
#   231,
#   17,
#   2,
#   7,
#   35,
#   61,
#   28,
#   52,
#   81,
#   50,
#   232,
#   6,
#   28,
#   66,
#   2,
#   9,
#   22,
#   36,
#   4,
#   54,
#   1,
#   35,
#   34,
#   87,
#   233,
#   234],
#  [235, 236],
#  [235, 236, 82],
#  [235, 236, 82, 8],
#  [235, 236, 82, 8, 53],
#  [235, 236, 82, 8, 53, 133],
#  [237, 6],
#  [237, 6, 1],
#  [237, 6, 1, 238],
#  [237, 6, 1, 238, 13],
#  [237, 6, 1, 238, 13, 39],
#  [27, 10],
#  [27, 10, 3],
#  [27, 10, 3, 239],
#  [27, 10, 3, 239, 240],
#  [27, 10, 3, 239, 240, 14],
#  [27, 10, 3, 239, 240, 14, 71],
#  [27, 10, 3, 239, 240, 14, 71, 6],
#  [27, 10, 3, 239, 240, 14, 71, 6, 5],
#  [27, 10, 3, 239, 240, 14, 71, 6, 5, 63],
#  [27, 10, 3, 239, 240, 14, 71, 6, 5, 63, 86],
#  [27, 10, 3, 239, 240, 14, 71, 6, 5, 63, 86, 1],
#  [27, 10, 3, 239, 240, 14, 71, 6, 5, 63, 86, 1, 32],
#  [2, 9],
#  [2, 9, 7],
#  [2, 9, 7, 4],
#  [2, 9, 7, 4, 241],
#  [2, 9, 7, 4, 241, 5],
#  [2, 9, 7, 4, 241, 5, 55],
#  [2, 9, 7, 4, 241, 5, 55, 134],
#  [2, 9, 7, 4, 241, 5, 55, 134, 133],
#  [2, 9, 7, 4, 241, 5, 55, 134, 133, 14],
#  [2, 9, 7, 4, 241, 5, 55, 134, 133, 14, 37],
#  [2, 9, 7, 4, 241, 5, 55, 134, 133, 14, 37, 77],
#  [2, 9, 7, 4, 241, 5, 55, 134, 133, 14, 37, 77, 17],
#  [2, 9, 7, 4, 241, 5, 55, 134, 133, 14, 37, 77, 17, 33],
#  [2, 9, 7, 4, 241, 5, 55, 134, 133, 14, 37, 77, 17, 33, 242],
#  [2, 9, 7, 4, 241, 5, 55, 134, 133, 14, 37, 77, 17, 33, 242, 9],
#  [2, 9, 7, 4, 241, 5, 55, 134, 133, 14, 37, 77, 17, 33, 242, 9, 60],
#  [2, 9, 7, 4, 241, 5, 55, 134, 133, 14, 37, 77, 17, 33, 242, 9, 60, 2],
#  [2, 9, 7, 4, 241, 5, 55, 134, 133, 14, 37, 77, 17, 33, 242, 9, 60, 2, 16],
#  [2, 9, 7, 4, 241, 5, 55, 134, 133, 14, 37, 77, 17, 33, 242, 9, 60, 2, 16, 5],
#  [2,
#   9,
#   7,
#   4,
#   241,
#   5,
#   55,
#   134,
#   133,
#   14,
#   37,
#   77,
#   17,
#   33,
#   242,
#   9,
#   60,
#   2,
#   16,
#   5,
#   135],
#  [2,
#   9,
#   7,
#   4,
#   241,
#   5,
#   55,
#   134,
#   133,
#   14,
#   37,
#   77,
#   17,
#   33,
#   242,
#   9,
#   60,
#   2,
#   16,
#   5,
#   135,
#   20],
#  [2,
#   9,
#   7,
#   4,
#   241,
#   5,
#   55,
#   134,
#   133,
#   14,
#   37,
#   77,
#   17,
#   33,
#   242,
#   9,
#   60,
#   2,
#   16,
#   5,
#   135,
#   20,
#   135],
#  [2,
#   9,
#   7,
#   4,
#   241,
#   5,
#   55,
#   134,
#   133,
#   14,
#   37,
#   77,
#   17,
#   33,
#   242,
#   9,
#   60,
#   2,
#   16,
#   5,
#   135,
#   20,
#   135,
#   63],
#  [2,
#   9,
#   7,
#   4,
#   241,
#   5,
#   55,
#   134,
#   133,
#   14,
#   37,
#   77,
#   17,
#   33,
#   242,
#   9,
#   60,
#   2,
#   16,
#   5,
#   135,
#   20,
#   135,
#   63,
#   136],
#  [2,
#   9,
#   7,
#   4,
#   241,
#   5,
#   55,
#   134,
#   133,
#   14,
#   37,
#   77,
#   17,
#   33,
#   242,
#   9,
#   60,
#   2,
#   16,
#   5,
#   135,
#   20,
#   135,
#   63,
#   136,
#   32],
#  [23, 3],
#  [23, 3, 46],
#  [23, 3, 46, 1],
#  [23, 3, 46, 1, 12],
#  [23, 3, 46, 1, 12, 76],
#  [23, 3, 46, 1, 12, 76, 10],
#  [23, 3, 46, 1, 12, 76, 10, 3],
#  [23, 3, 46, 1, 12, 76, 10, 3, 243],
#  [23, 3, 46, 1, 12, 76, 10, 3, 243, 244],
#  [23, 3, 46, 1, 12, 76, 10, 3, 243, 244, 47],
#  [23, 3, 46, 1, 12, 76, 10, 3, 243, 244, 47, 137],
#  [23, 3, 46, 1, 12, 76, 10, 3, 243, 244, 47, 137, 245],
#  [44, 246],
#  [44, 246, 247],
#  [44, 246, 247, 47],
#  [44, 246, 247, 47, 137],
#  [44, 246, 247, 47, 137, 63],
#  [44, 246, 247, 47, 137, 63, 14],
#  [44, 246, 247, 47, 137, 63, 14, 1],
#  [44, 246, 247, 47, 137, 63, 14, 1, 63],
#  [44, 246, 247, 47, 137, 63, 14, 1, 63, 136],
#  [44, 246, 247, 47, 137, 63, 14, 1, 63, 136, 55],
#  [44, 246, 247, 47, 137, 63, 14, 1, 63, 136, 55, 134],
#  [3, 25],
#  [3, 25, 124],
#  [3, 25, 124, 125],
#  [3, 25, 124, 125, 126],
#  [3, 25, 124, 125, 126, 17],
#  [3, 25, 124, 125, 126, 17, 3],
#  [3, 25, 124, 125, 126, 17, 3, 25],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1, 19],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1, 19, 20],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1, 19, 20, 1],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1, 19, 20, 1, 38],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1, 19, 20, 1, 38, 11],
#  [3, 25, 124, 125, 126, 17, 3, 25, 53, 36, 4, 21, 1, 19, 20, 1, 38, 11, 127],
#  [3,
#   25,
#   124,
#   125,
#   126,
#   17,
#   3,
#   25,
#   53,
#   36,
#   4,
#   21,
#   1,
#   19,
#   20,
#   1,
#   38,
#   11,
#   127,
#   3],
#  [3,
#   25,
#   124,
#   125,
#   126,
#   17,
#   3,
#   25,
#   53,
#   36,
#   4,
#   21,
#   1,
#   19,
#   20,
#   1,
#   38,
#   11,
#   127,
#   3,
#   24],
#  [2, 7],
#  [2, 7, 4],
#  [2, 7, 4, 60],
#  [2, 7, 4, 60, 61],
#  [2, 7, 4, 60, 61, 56],
#  [2, 7, 4, 60, 61, 56, 128],
#  [2, 7, 4, 60, 61, 56, 128, 5],
#  [2, 7, 4, 60, 61, 56, 128, 5, 58],
#  [2, 7, 4, 60, 61, 56, 128, 5, 58, 62],
#  [2, 7, 4, 60, 61, 56, 128, 5, 58, 62, 80],
#  [2, 7, 4, 60, 61, 56, 128, 5, 58, 62, 80, 30],
#  [2, 7, 4, 60, 61, 56, 128, 5, 58, 62, 80, 30, 248],
#  [2, 7, 4, 60, 61, 56, 128, 5, 58, 62, 80, 30, 248, 57],
#  [138, 17],
#  [138, 17, 89],
#  [138, 17, 89, 90],
#  [138, 17, 89, 90, 116],
#  [138, 17, 89, 90, 116, 129],
#  [11, 8],
#  [11, 8, 1],
#  [11, 8, 1, 249],
#  [11, 8, 1, 249, 4],
#  [11, 8, 1, 249, 4, 43],
#  [11, 8, 1, 249, 4, 43, 1],
#  [11, 8, 1, 249, 4, 43, 1, 138],
#  [250, 74],
#  [250, 74, 108],
#  [250, 74, 108, 251],
#  [2, 7],
#  [2, 7, 4],
#  [2, 7, 4, 18],
#  [2, 7, 4, 18, 1],
#  [2, 7, 4, 18, 1, 118],
#  [2, 7, 4, 18, 1, 118, 39],
#  [2, 7, 4, 18, 1, 118, 39, 6],
#  [2, 7, 4, 18, 1, 118, 39, 6, 28],
#  [2, 7, 4, 18, 1, 118, 39, 6, 28, 52],
#  [2, 7],
#  [2, 7, 4],
#  [2, 7, 4, 252],
#  [2, 7, 4, 252, 15],
#  [2, 7, 4, 252, 15, 1],
#  [2, 7, 4, 252, 15, 1, 13],
#  [2, 7, 4, 252, 15, 1, 13, 253],
#  [3, 25],
#  [3, 25, 254],
#  [3, 25, 254, 76],
#  [3, 25, 254, 76, 109],
#  [3, 25, 254, 76, 109, 10],
#  [3, 25, 254, 76, 109, 10, 3],
#  [3, 25, 254, 76, 109, 10, 3, 18],
#  [3, 25, 254, 76, 109, 10, 3, 18, 19],
#  [3, 25, 254, 76, 109, 10, 3, 18, 19, 6],
#  [3, 25, 254, 76, 109, 10, 3, 18, 19, 6, 1],
#  [3, 25, 254, 76, 109, 10, 3, 18, 19, 6, 1, 139],
#  [3, 25, 254, 76, 109, 10, 3, 18, 19, 6, 1, 139, 69],
#  [2, 9],
#  [2, 9, 43],
#  [2, 9, 43, 5],
#  [2, 9, 43, 5, 117],
#  [2, 9, 43, 5, 117, 4],
#  [2, 9, 43, 5, 117, 4, 18],
#  [2, 9, 43, 5, 117, 4, 18, 39],
#  [2, 9, 43, 5, 117, 4, 18, 39, 6],
#  [2, 9, 43, 5, 117, 4, 18, 39, 6, 139],
#  [2, 9, 43, 5, 117, 4, 18, 39, 6, 139, 69],
#  [2, 9, 43, 5, 117, 4, 18, 39, 6, 139, 69, 14],
#  [2, 9, 43, 5, 117, 4, 18, 39, 6, 139, 69, 14, 37],
#  [2, 9, 43, 5, 117, 4, 18, 39, 6, 139, 69, 14, 37, 77],
#  [2, 9, 43, 5, 117, 4, 18, 39, 6, 139, 69, 14, 37, 77, 45],
#  [2, 9, 43, 5, 117, 4, 18, 39, 6, 139, 69, 14, 37, 77, 45, 2],
#  [2, 9, 43, 5, 117, 4, 18, 39, 6, 139, 69, 14, 37, 77, 45, 2, 18],
#  [2, 9, 43, 5, 117, 4, 18, 39, 6, 139, 69, 14, 37, 77, 45, 2, 18, 16],
#  [2, 9, 43, 5, 117, 4, 18, 39, 6, 139, 69, 14, 37, 77, 45, 2, 18, 16, 1],
#  [2, 9, 43, 5, 117, 4, 18, 39, 6, 139, 69, 14, 37, 77, 45, 2, 18, 16, 1, 255],
#  [2,
#   9,
#   43,
#   5,
#   117,
#   4,
#   18,
#   39,
#   6,
#   139,
#   69,
#   14,
#   37,
#   77,
#   45,
#   2,
#   18,
#   16,
#   1,
#   255,
#   42],
#  [3, 7],
#  [3, 7, 131],
#  [3, 7, 131, 256],
#  [3, 7, 131, 256, 89],
#  [3, 7, 131, 256, 89, 90],
#  [3, 7, 131, 256, 89, 90, 8],
#  [3, 7, 131, 256, 89, 90, 8, 5],
#  [3, 7, 131, 256, 89, 90, 8, 5, 73],
#  [3, 7, 131, 256, 89, 90, 8, 5, 73, 6],
#  [3, 7, 131, 256, 89, 90, 8, 5, 73, 6, 31],
#  [3, 7, 131, 256, 89, 90, 8, 5, 73, 6, 31, 12],
#  [3, 7, 131, 256, 89, 90, 8, 5, 73, 6, 31, 12, 11],
#  [3, 7, 131, 256, 89, 90, 8, 5, 73, 6, 31, 12, 11, 257],
#  [3, 7, 131, 256, 89, 90, 8, 5, 73, 6, 31, 12, 11, 257, 258],
#  [3, 7, 131, 256, 89, 90, 8, 5, 73, 6, 31, 12, 11, 257, 258, 89],
#  [3, 7, 131, 256, 89, 90, 8, 5, 73, 6, 31, 12, 11, 257, 258, 89, 90]]

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,  91,   1],
#        [  0,   0,   0, ...,  91,   1,  12],
#        [  0,   0,   0, ...,   0,  11,   8],
#        ...,
#        [  0,   0,   0, ...,  11, 257, 258],
#        [  0,   0,   0, ..., 257, 258,  89],
#        [  0,   0,   0, ..., 258,  89,  90]], dtype=int32)

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (801, 56)

# %%
y.shape
# Out:
# (801,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=283)

# %%
y.shape
# Out:
# (801, 283)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding

model = Sequential()
model.add(Embedding(283, 100, input_length=56))
model.add(LSTM(150, return_sequences=True))  # Output sequences
model.add(LSTM(155))  # Second LSTM layer should receive sequences
model.add(Dense(283, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 56, 100)           28300
#
#  lstm_8 (LSTM)               (None, 56, 150)           150600
#
#  lstm_9 (LSTM)               (None, 155)               189720
#
#  dense_1 (Dense)             (None, 283)               44148
#
# =================================================================
# Total params: 412768 (1.57 MB)
# Trainable params: 412768 (1.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 16s 342ms/step - loss: 5.3695 - accuracy: 0.0762
# Epoch 2/100
# 26/26 [==============================] - 6s 239ms/step - loss: 5.0496 - accuracy: 0.0836
# Epoch 3/100
# 26/26 [==============================] - 5s 199ms/step - loss: 4.9722 - accuracy: 0.0836
# Epoch 4/100
# 26/26 [==============================] - 6s 251ms/step - loss: 4.9491 - accuracy: 0.0836
# Epoch 5/100
# 26/26 [==============================] - 5s 195ms/step - loss: 4.9510 - accuracy: 0.0836
# Epoch 6/100
# 26/26 [==============================] - 6s 237ms/step - loss: 4.9387 - accuracy: 0.0836
# Epoch 7/100
# 26/26 [==============================] - 5s 192ms/step - loss: 4.9342 - accuracy: 0.0836
# Epoch 8/100
# 26/26 [==============================] - 6s 236ms/step - loss: 4.9353 - accuracy: 0.0836
# Epoch 9/100
# 26/26 [==============================] - 5s 188ms/step - loss: 4.9248 - accuracy: 0.0836
# Epoch 10/100
# 26/26 [==============================] - 5s 192ms/step - loss: 4.8881 - accuracy: 0.0836
# Epoch 11/100
# 26/26 [==============================] - 6s 223ms/step - loss: 4.8224 - accuracy: 0.0836
# Epoch 12/100
# 26/26 [==============================] - 5s 198ms/step - loss: 4.7337 - accuracy: 0.0849
# Epoch 13/100
# 26/26 [==============================] - 7s 257ms/step - loss: 4.6270 - accuracy: 0.0974
# Epoch 14/100
# 26/26 [==============================] - 5s 188ms/step - loss: 4.5339 - accuracy: 0.1061
# Epoch 15/100
# 26/26 [==============================] - 6s 230ms/step - loss: 4.4141 - accuracy: 0.1161
# Epoch 16/100
# 26/26 [==============================] - 5s 185ms/step - loss: 4.2945 - accuracy: 0.1248
# Epoch 17/100
# 26/26 [==============================] - 7s 257ms/step - loss: 4.1598 - accuracy: 0.1336
# Epoch 18/100
# 26/26 [==============================] - 5s 201ms/step - loss: 4.0348 - accuracy: 0.1486
# Epoch 19/100
# 26/26 [==============================] - 7s 261ms/step - loss: 3.8900 - accuracy: 0.1660
# Epoch 20/100
# 26/26 [==============================] - 6s 210ms/step - loss: 3.7671 - accuracy: 0.2085
# Epoch 21/100
# 26/26 [==============================] - 5s 185ms/step - loss: 3.6236 - accuracy: 0.2160
# Epoch 22/100
# 26/26 [==============================] - 6s 238ms/step - loss: 3.4893 - accuracy: 0.2409
# Epoch 23/100
# 26/26 [==============================] - 5s 183ms/step - loss: 3.3564 - accuracy: 0.2422
# Epoch 24/100
# 26/26 [==============================] - 6s 225ms/step - loss: 3.2514 - accuracy: 0.2597
# Epoch 25/100
# 26/26 [==============================] - 5s 183ms/step - loss: 3.1320 - accuracy: 0.2859
# Epoch 26/100
# 26/26 [==============================] - 5s 201ms/step - loss: 3.0212 - accuracy: 0.3059
# Epoch 27/100
# 26/26 [==============================] - 6s 207ms/step - loss: 2.9340 - accuracy: 0.3084
# Epoch 28/100
# 26/26 [==============================] - 5s 185ms/step - loss: 2.8078 - accuracy: 0.3396
# Epoch 29/100
# 26/26 [==============================] - 6s 235ms/step - loss: 2.7000 - accuracy: 0.3620
# Epoch 30/100
# 26/26 [==============================] - 5s 187ms/step - loss: 2.6026 - accuracy: 0.3870
# Epoch 31/100
# 26/26 [==============================] - 6s 236ms/step - loss: 2.5141 - accuracy: 0.4020
# Epoch 32/100
# 26/26 [==============================] - 5s 188ms/step - loss: 2.4088 - accuracy: 0.4332
# Epoch 33/100
# 26/26 [==============================] - 6s 229ms/step - loss: 2.3249 - accuracy: 0.4395
# Epoch 34/100
# 26/26 [==============================] - 5s 189ms/step - loss: 2.2565 - accuracy: 0.4819
# Epoch 35/100
# 26/26 [==============================] - 5s 183ms/step - loss: 2.1629 - accuracy: 0.4969
# Epoch 36/100
# 26/26 [==============================] - 6s 233ms/step - loss: 2.0634 - accuracy: 0.5194
# Epoch 37/100
# 26/26 [==============================] - 5s 187ms/step - loss: 1.9795 - accuracy: 0.5481
# Epoch 38/100
# 26/26 [==============================] - 6s 234ms/step - loss: 1.9305 - accuracy: 0.5605
# Epoch 39/100
# 26/26 [==============================] - 5s 183ms/step - loss: 1.8189 - accuracy: 0.5905
# Epoch 40/100
# 26/26 [==============================] - 6s 234ms/step - loss: 1.7665 - accuracy: 0.5955
# Epoch 41/100
# 26/26 [==============================] - 5s 184ms/step - loss: 1.7225 - accuracy: 0.6117
# Epoch 42/100
# 26/26 [==============================] - 5s 187ms/step - loss: 1.6390 - accuracy: 0.6429
# Epoch 43/100
# 26/26 [==============================] - 6s 234ms/step - loss: 1.5610 - accuracy: 0.6467
# Epoch 44/100
# 26/26 [==============================] - 5s 188ms/step - loss: 1.5234 - accuracy: 0.6704
# Epoch 45/100
# 26/26 [==============================] - 6s 236ms/step - loss: 1.4403 - accuracy: 0.6929
# Epoch 46/100
# 26/26 [==============================] - 5s 185ms/step - loss: 1.4340 - accuracy: 0.6854
# Epoch 47/100
# 26/26 [==============================] - 6s 237ms/step - loss: 1.3436 - accuracy: 0.7278
# Epoch 48/100
# 26/26 [==============================] - 5s 197ms/step - loss: 1.2825 - accuracy: 0.7403
# Epoch 49/100
# 26/26 [==============================] - 7s 270ms/step - loss: 1.2109 - accuracy: 0.7628
# Epoch 50/100
# 26/26 [==============================] - 5s 194ms/step - loss: 1.1846 - accuracy: 0.7765
# Epoch 51/100
# 26/26 [==============================] - 5s 188ms/step - loss: 1.1226 - accuracy: 0.7878
# Epoch 52/100
# 26/26 [==============================] - 6s 228ms/step - loss: 1.0895 - accuracy: 0.8027
# Epoch 53/100
# 26/26 [==============================] - 5s 188ms/step - loss: 1.0294 - accuracy: 0.8215
# Epoch 54/100
# 26/26 [==============================] - 6s 232ms/step - loss: 0.9927 - accuracy: 0.8140
# Epoch 55/100
# 26/26 [==============================] - 5s 188ms/step - loss: 0.9523 - accuracy: 0.8377
# Epoch 56/100
# 26/26 [==============================] - 6s 219ms/step - loss: 0.9313 - accuracy: 0.8352
# Epoch 57/100
# 26/26 [==============================] - 5s 187ms/step - loss: 0.8864 - accuracy: 0.8340
# Epoch 58/100
# 26/26 [==============================] - 5s 184ms/step - loss: 0.8808 - accuracy: 0.8489
# Epoch 59/100
# 26/26 [==============================] - 6s 232ms/step - loss: 0.8484 - accuracy: 0.8527
# Epoch 60/100
# 26/26 [==============================] - 5s 182ms/step - loss: 0.7954 - accuracy: 0.8552
# Epoch 61/100
# 26/26 [==============================] - 6s 230ms/step - loss: 0.7718 - accuracy: 0.8652
# Epoch 62/100
# 26/26 [==============================] - 5s 184ms/step - loss: 0.7365 - accuracy: 0.8627
# Epoch 63/100
# 26/26 [==============================] - 5s 203ms/step - loss: 0.7193 - accuracy: 0.8727
# Epoch 64/100
# 26/26 [==============================] - 5s 203ms/step - loss: 0.7190 - accuracy: 0.8627
# Epoch 65/100
# 26/26 [==============================] - 5s 182ms/step - loss: 0.6969 - accuracy: 0.8739
# Epoch 66/100
# 26/26 [==============================] - 6s 233ms/step - loss: 0.6718 - accuracy: 0.8777
# Epoch 67/100
# 26/26 [==============================] - 5s 183ms/step - loss: 0.6359 - accuracy: 0.8864
# Epoch 68/100
# 26/26 [==============================] - 6s 232ms/step - loss: 0.5998 - accuracy: 0.8914
# Epoch 69/100
# 26/26 [==============================] - 5s 181ms/step - loss: 0.5757 - accuracy: 0.8914
# Epoch 70/100
# 26/26 [==============================] - 5s 184ms/step - loss: 0.5588 - accuracy: 0.8951
# Epoch 71/100
# 26/26 [==============================] - 6s 219ms/step - loss: 0.5412 - accuracy: 0.9026
# Epoch 72/100
# 26/26 [==============================] - 5s 181ms/step - loss: 0.5282 - accuracy: 0.9001
# Epoch 73/100
# 26/26 [==============================] - 6s 230ms/step - loss: 0.5059 - accuracy: 0.9126
# Epoch 74/100
# 26/26 [==============================] - 6s 220ms/step - loss: 0.4857 - accuracy: 0.9126
# Epoch 75/100
# 26/26 [==============================] - 7s 285ms/step - loss: 0.4679 - accuracy: 0.9288
# Epoch 76/100
# 26/26 [==============================] - 5s 183ms/step - loss: 0.4782 - accuracy: 0.9189
# Epoch 77/100
# 26/26 [==============================] - 6s 234ms/step - loss: 0.4545 - accuracy: 0.9164
# Epoch 78/100
# 26/26 [==============================] - 5s 188ms/step - loss: 0.4415 - accuracy: 0.9213
# Epoch 79/100
# 26/26 [==============================] - 5s 212ms/step - loss: 0.4340 - accuracy: 0.9226
# Epoch 80/100
# 26/26 [==============================] - 7s 250ms/step - loss: 0.4173 - accuracy: 0.9238
# Epoch 81/100
# 26/26 [==============================] - 5s 186ms/step - loss: 0.3983 - accuracy: 0.9251
# Epoch 82/100
# 26/26 [==============================] - 6s 232ms/step - loss: 0.3868 - accuracy: 0.9313
# Epoch 83/100
# 26/26 [==============================] - 5s 187ms/step - loss: 0.3769 - accuracy: 0.9288
# Epoch 84/100
# 26/26 [==============================] - 6s 230ms/step - loss: 0.3706 - accuracy: 0.9276
# Epoch 85/100
# 26/26 [==============================] - 5s 187ms/step - loss: 0.3656 - accuracy: 0.9313
# Epoch 86/100
# 26/26 [==============================] - 5s 183ms/step - loss: 0.3501 - accuracy: 0.9363
# Epoch 87/100
# 26/26 [==============================] - 6s 222ms/step - loss: 0.3583 - accuracy: 0.9313
# Epoch 88/100
# 26/26 [==============================] - 5s 186ms/step - loss: 0.3371 - accuracy: 0.9363
# Epoch 89/100
# 26/26 [==============================] - 6s 227ms/step - loss: 0.3266 - accuracy: 0.9363
# Epoch 90/100
# 26/26 [==============================] - 5s 187ms/step - loss: 0.3390 - accuracy: 0.9288
# Epoch 91/100
# 26/26 [==============================] - 6s 233ms/step - loss: 0.3178 - accuracy: 0.9363
# Epoch 92/100
# 26/26 [==============================] - 5s 182ms/step - loss: 0.3198 - accuracy: 0.9376
# Epoch 93/100
# 26/26 [==============================] - 5s 187ms/step - loss: 0.3069 - accuracy: 0.9388
# Epoch 94/100
# 26/26 [==============================] - 6s 232ms/step - loss: 0.2926 - accuracy: 0.9413
# Epoch 95/100
# 26/26 [==============================] - 5s 185ms/step - loss: 0.2816 - accuracy: 0.9388
# Epoch 96/100
# 26/26 [==============================] - 6s 229ms/step - loss: 0.2776 - accuracy: 0.9376
# Epoch 97/100
# 26/26 [==============================] - 5s 185ms/step - loss: 0.2689 - accuracy: 0.9463
# Epoch 98/100
# 26/26 [==============================] - 6s 228ms/step - loss: 0.2642 - accuracy: 0.9438
# Epoch 99/100
# 26/26 [==============================] - 5s 180ms/step - loss: 0.2604 - accuracy: 0.9451
# Epoch 100/100
# 26/26 [==============================] - 5s 185ms/step - loss: 0.2607 - accuracy: 0.9426

# %%
import time
import numpy as np
text = "what is the fee"

for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 [==============================] - 1s 903ms/step
# what is the fee of
# 1/1 [==============================] - 0s 38ms/step
# what is the fee of the
# 1/1 [==============================] - 0s 59ms/step
# what is the fee of the mentorship
# 1/1 [==============================] - 0s 43ms/step
# what is the fee of the mentorship program
# 1/1 [==============================] - 0s 38ms/step
# what is the fee of the mentorship program in
# 1/1 [==============================] - 0s 48ms/step
# what is the fee of the mentorship program in the
# 1/1 [==============================] - 0s 42ms/step
# what is the fee of the mentorship program in the 799
# 1/1 [==============================] - 0s 41ms/step
# what is the fee of the mentorship program in the 799 7
# 1/1 [==============================] - 0s 38ms/step
# what is the fee of the mentorship program in the 799 7 once
# 1/1 [==============================] - 0s 36ms/step
# what is the fee of the mentorship program in the 799 7 once you

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'you': 2,
#  'i': 3,
#  'to': 4,
#  'a': 5,
#  'of': 6,
#  'have': 7,
#  'is': 8,
#  'will': 9,
#  'can': 10,
#  'what': 11,
#  'program': 12,
#  'course': 13,
#  'in': 14,
#  'all': 15,
#  'for': 16,
#  'and': 17,
#  'pay': 18,
#  'payment': 19,
#  'on': 20,
#  'make': 21,
#  'be': 22,
#  'if': 23,
#  'do': 24,
#  'am': 25,
#  'subscription': 26,
#  'where': 27,
#  'rs': 28,
#  'we': 29,
#  'campusx': 30,
#  'this': 31,
#  'session': 32,
#  'our': 33,
#  'sessions': 34,
#  'paid': 35,
#  'able': 36,
#  'your': 37,
#  'website': 38,
#  'fee': 39,
#  'data': 40,
#  'monthly': 41,
#  'month': 42,
#  'get': 43,
#  'yes': 44,
#  'once': 45,
#  'join': 46,
#  'past': 47,
#  'feb': 48,
#  'science': 49,
#  '7': 50,
#  'so': 51,
#  '5600': 52,
#  'not': 53,
#  'watch': 54,
#  'google': 55,
#  'by': 56,
#  'com': 57,
#  'mail': 58,
#  'from': 59,
#  'contact': 60,
#  'us': 61,
#  'at': 62,
#  'doubt': 63,
#  'mentorship': 64,
#  'payments': 65,
#  '799': 66,
#  'total': 67,
#  'duration': 68,
#  'months': 69,
#  'learning': 70,
#  'case': 71,
#  'https': 72,
#  'part': 73,
#  'are': 74,
#  'see': 75,
#  'late': 76,
#  'dashboard': 77,
#  'task': 78,
#  'don’t': 79,
#  'nitish': 80,
#  'or': 81,
#  'validity': 82,
#  '15th': 83,
#  'jan': 84,
#  'period': 85,
#  'after': 86,
#  'till': 87,
#  '21st': 88,
#  'placement': 89,
#  'assistance': 90,
#  'about': 91,
#  'follows': 92,
#  'model': 93,
#  'syllabus': 94,
#  'python': 95,
#  'ml': 96,
#  'studies': 97,
#  'here': 98,
#  'learnwith': 99,
#  'deep': 100,
#  'nlp': 101,
#  'no': 102,
#  'miss': 103,
#  'live': 104,
#  'recording': 105,
#  'class': 106,
#  'time': 107,
#  '2': 108,
#  'how': 109,
#  'absolutely': 110,
#  'middle': 111,
#  'anytime': 112,
#  'submit': 113,
#  'gmail': 114,
#  'registration': 115,
#  'related': 116,
#  'link': 117,
#  'entire': 118,
#  'suppose': 119,
#  'again': 120,
#  'days': 121,
#  'day': 122,
#  'refund': 123,
#  'living': 124,
#  'outside': 125,
#  'india': 126,
#  'should': 127,
#  'sending': 128,
#  'queries': 129,
#  'videos': 130,
#  'read': 131,
#  'but': 132,
#  'provided': 133,
#  'form': 134,
#  '1': 135,
#  'clearance': 136,
#  'week': 137,
#  'certificate': 138,
#  'earlier': 139,
#  'dsmp': 140,
#  '2023': 141,
#  'becomes': 142,
#  'approx': 143,
#  'covering': 144,
#  'following': 145,
#  'modules': 146,
#  'fundamentals': 147,
#  'libraries': 148,
#  'analysis': 149,
#  'sql': 150,
#  'maths': 151,
#  'machine': 152,
#  'algorithms': 153,
#  'practical': 154,
#  'mlops': 155,
#  'check': 156,
#  'detailed': 157,
#  'courses': 158,
#  '637339afe4b0615a1bbed390': 159,
#  'both': 160,
#  'program’s': 161,
#  'curriculum': 162,
#  'recorded': 163,
#  'even': 164,
#  'go': 165,
#  'back': 166,
#  'find': 167,
#  'schedule': 168,
#  'checkout': 169,
#  'sheet': 170,
#  'table': 171,
#  'docs': 172,
#  'spreadsheets': 173,
#  'd': 174,
#  '16ootax': 175,
#  'a6oraecg4emgexhqqpv3noqpyku7rj6arozk': 176,
#  'edit': 177,
#  'usp': 178,
#  'sharing': 179,
#  'roughly': 180,
#  'last': 181,
#  'hours': 182,
#  'language': 183,
#  'spoken': 184,
#  'instructor': 185,
#  'during': 186,
#  'hinglish': 187,
#  'informed': 188,
#  'upcoming': 189,
#  'side': 190,
#  'before': 191,
#  'every': 192,
#  'become': 193,
#  'user': 194,
#  'non': 195,
#  'tech': 196,
#  'background': 197,
#  'lectures': 198,
#  'content': 199,
#  'provide': 200,
#  'with': 201,
#  'solutions': 202,
#  'self': 203,
#  'evaluate': 204,
#  'yourself': 205,
#  'questions': 206,
#  'youtube': 207,
#  'channel': 208,
#  'amount': 209,
#  'unfortunately': 210,
#  'then': 211,
#  '1st': 212,
#  '30': 213,
#  'essentially': 214,
#  'wait': 215,
#  'end': 216,
#  'like': 217,
#  'making': 218,
#  'policy': 219,
#  'made': 220,
#  'post': 221,
#  'when': 222,
#  'view': 223,
#  'one': 224,
#  'tricky': 225,
#  'carefully': 226,
#  'valid': 227,
#  'purchased': 228,
#  '20th': 229,
#  'purchase': 230,
#  'over': 231,
#  'installments': 232,
#  'aug': 233,
#  '2024': 234,
#  'why': 235,
#  'lifetime': 236,
#  'because': 237,
#  'low': 238,
#  'reach': 239,
#  'out': 240,
#  'fill': 241,
#  'team': 242,
#  'still': 243,
#  'ask': 244,
#  'doubts': 245,
#  'just': 246,
#  'select': 247,
#  'gmai': 248,
#  'criteria': 249,
#  'there': 250,
#  'criterias': 251,
#  'attempt': 252,
#  'assessments': 253,
#  'joining': 254,
#  'current': 255,
#  'that': 256,
#  'comes': 257,
#  'under': 258}
